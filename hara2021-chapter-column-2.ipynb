# %% [markdown]
# # 「Python による経済・経営分析のための実践的データサイエンス」第3章 (pp.84-92)

# %%
#edinet-python を導入する
# !pip install edinet-python
# Out:
# Collecting edinet-python
#   Downloading edinet-python-0.1.18.tar.gz (1.6 MB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\murak\anaconda3\lib\site-packages (from edinet-python) (2.25.1)
# Requirement already satisfied: beautifulsoup4>=4.7.1 in c:\users\murak\anaconda3\lib\site-packages (from edinet-python) (4.9.3)
# Requirement already satisfied: lxml>=4.3.3 in c:\users\murak\anaconda3\lib\site-packages (from edinet-python) (4.6.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\murak\anaconda3\lib\site-packages (from beautifulsoup4>=4.7.1->edinet-python) (2.2.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\murak\anaconda3\lib\site-packages (from requests>=2.21.0->edinet-python) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\murak\anaconda3\lib\site-packages (from requests>=2.21.0->edinet-python) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\murak\anaconda3\lib\site-packages (from requests>=2.21.0->edinet-python) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\murak\anaconda3\lib\site-packages (from requests>=2.21.0->edinet-python) (2020.12.5)
# Building wheels for collected packages: edinet-python
#   Building wheel for edinet-python (setup.py): started
#   Building wheel for edinet-python (setup.py): finished with status 'done'
#   Created wheel for edinet-python: filename=edinet_python-0.1.18-py3-none-any.whl size=17218 sha256=c9ccafe6bb01d70cd2d6b2e1ba818aa1ca5f023efd5d33248042de05f9f3d912
#   Stored in directory: c:\users\murak\appdata\local\pip\cache\wheels\d2\a3\1f\d06048862238727c5cfc2e822cb47fbfffed2206fdd2a6b543
# Successfully built edinet-python
# Installing collected packages: edinet-python
# Successfully installed edinet-python-0.1.18

# %%
#edinet をインポートする
import edinet

#2020年6月1日のドキュメントを取得する
documents = edinet.api.documents.get("2022-10-03")
print(f"Number of documents is {len(documents.list)}")
print(f"Title of first document is {documents.list[0].title}")

print(documents)

#取り出した報告書を確認する
for i in range(len(documents.list)):
        print(documents.list[i].title)
# Out:
# C:\Users\murak\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'disclosure.edinet-fsa.go.jp'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Number of documents is 249
# Title of first document is 訂正有価証券届出書（内国投資信託受益証券）
# <edinet.models.documents.Documents object at 0x0000020749812820>
# 訂正有価証券届出書（内国投資信託受益証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 訂正有価証券報告書－第98期(令和3年1月1日－令和3年12月31日)
# 訂正有価証券届出書（内国投資信託受益証券）
# 有価証券報告書（内国投資信託受益証券）－第17期(令和4年1月11日－令和4年7月10日)
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 有価証券届出書（内国投資信託受益証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 有価証券報告書（内国投資信託受益証券）－第13期(令和4年1月11日－令和4年7月10日)
# 有価証券届出書（内国投資信託受益証券）
# 発行登録追補書類
# 臨時報告書
# 有価証券報告書（内国投資信託受益証券）－第10期(令和4年1月11日－令和4年7月10日)
# 臨時報告書（内国特定有価証券）
# 有価証券届出書（内国投資信託受益証券）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書（内国特定有価証券）
# 有価証券報告書（内国投資信託受益証券）－第10期(令和4年1月11日－令和4年7月10日)
# 臨時報告書（内国特定有価証券）
# 有価証券届出書（内国投資信託受益証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 有価証券報告書（内国投資信託受益証券）－第10期(令和4年1月11日－令和4年7月10日)
# 臨時報告書（内国特定有価証券）
# 変更報告書（短期大量譲渡）
# 臨時報告書（内国特定有価証券）
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第21期(令和4年1月7日－令和5年1月6日)
# 有価証券報告書（内国投資信託受益証券）－第18期(令和4年1月11日－令和4年7月10日)
# 有価証券届出書（内国投資信託受益証券）
# 臨時報告書（内国特定有価証券）
# 有価証券報告書（内国投資信託受益証券）－第21期(令和3年7月11日－令和4年7月10日)
# 臨時報告書
# 有価証券届出書（内国投資信託受益証券）
# 変更報告書
# 有価証券報告書（内国投資信託受益証券）－第21期(令和3年7月11日－令和4年7月10日)
# 四半期報告書－第67期第2四半期(令和4年5月21日－令和4年8月20日)
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 有価証券届出書（内国投資信託受益証券）
# 確認書
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 発行登録追補書類
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 有価証券届出書（内国投資信託受益証券）
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 四半期報告書－第38期第2四半期(令和4年5月21日－令和4年8月20日)
# 有価証券届出書（内国投資信託受益証券）
# 確認書
# 半期報告書（内国投資信託受益証券）－第8期(令和4年1月11日－令和5年1月10日)
# 有価証券届出書（内国投資信託受益証券）
# 臨時報告書（内国特定有価証券）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 変更報告書
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書（内国特定有価証券）
# 臨時報告書
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書（内国特定有価証券）
# 臨時報告書
# 発行登録書（株券､社債券等）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 確認書
# 公開買付届出書
# 臨時報告書
# 有価証券届出書（参照方式）
# 訂正発行登録書
# 訂正有価証券届出書（内国信託受益証券等）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 訂正有価証券報告書
# 訂正半期報告書
# 訂正発行登録書
# 訂正発行登録書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 臨時報告書
# 訂正有価証券届出書（内国資産流動化証券）
# 臨時報告書
# 大量保有報告書
# 訂正発行登録書
# 臨時報告書
# 大量保有報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 訂正半期報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 訂正報告書（大量保有報告書・変更報告書）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書（外国特定有価証券）
# 大量保有報告書
# 有価証券報告書（内国信託受益証券等）－第2期(令和4年1月18日－令和4年7月19日)
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 臨時報告書
# 変更報告書
# 有価証券報告書（内国信託受益証券等）－第1期(令和3年12月29日－令和4年7月19日)
# 大量保有報告書
# 有価証券報告書（内国信託受益証券等）－第1期(令和3年12月29日－令和4年7月19日)
# 臨時報告書
# 大量保有報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 大量保有報告書
# 訂正発行登録書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 意見表明報告書
# 訂正報告書（大量保有報告書・変更報告書）
# 四半期報告書－第54期第2四半期(令和4年5月21日－令和4年8月20日)
# 確認書
# 大量保有報告書
# 臨時報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 臨時報告書
# 訂正有価証券届出書（内国投資信託受益証券）
# 訂正有価証券届出書（内国投資信託受益証券）
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 有価証券届出書（組込方式）
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 訂正有価証券届出書（新規公開時）
# 訂正有価証券届出書（新規公開時）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 訂正臨時報告書
# 臨時報告書
# 臨時報告書
# 変更報告書
# 臨時報告書
# 四半期報告書－第24期第3四半期(令和4年6月1日－令和4年8月31日)
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 確認書
# 臨時報告書
# 訂正有価証券報告書－第43期(令和3年4月1日－令和4年3月31日)
# 変更報告書（短期大量譲渡）
# 訂正確認書
# 訂正報告書（大量保有報告書・変更報告書）
# 臨時報告書
# 変更報告書
# 臨時報告書
# 変更報告書
# 臨時報告書
# 変更報告書
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書（特例対象株券等）
# 有価証券届出書（参照方式）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 大量保有報告書
# 訂正発行登録書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 大量保有報告書
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 臨時報告書
# 変更報告書
# 変更報告書（特例対象株券等）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 大量保有報告書（特例対象株券等）
# 変更報告書
# 変更報告書（特例対象株券等）
# 大量保有報告書（特例対象株券等）
# 臨時報告書
# 臨時報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書（特例対象株券等）
# 臨時報告書
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 大量保有報告書（特例対象株券等）
# 大量保有報告書（特例対象株券等）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 臨時報告書
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 変更報告書（短期大量譲渡）
# 変更報告書（特例対象株券等）
# 変更報告書
# 変更報告書（特例対象株券等）
# 変更報告書（特例対象株券等）
# 大量保有報告書（特例対象株券等）
# 臨時報告書
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 変更報告書
# 訂正報告書（大量保有報告書・変更報告書）
# 自己株券買付状況報告書（法２４条の６第１項に基づくもの）
# 臨時報告書
# 臨時報告書
# 訂正報告書（大量保有報告書・変更報告書）
# 訂正有価証券届出書（組織再編成・上場）
# 発行登録追補書類
# 臨時報告書

# %%
from pathlib import Path
import edinet

#データを取得して, PDF 版とXBRL 版を保存する
#ここでは、株式会社ブロードバンドタワーの有価証券報告書を取得する
#xbrl_path = edinet.api.document.get_xbrl("S100I8ZU", save_dir=Path.cwd())
#pdf_path = edinet.api.document.get_pdf("S100I8ZU", save_dir=Path.cwd())
xbrl_path = edinet.api.document.get_xbrl("S100OULM", save_dir=Path.cwd())
pdf_path = edinet.api.document.get_pdf("S100OULM", save_dir=Path.cwd())
# Out:
# C:\Users\murak\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'disclosure.edinet-fsa.go.jp'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\murak\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'disclosure.edinet-fsa.go.jp'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
from edinet.xbrl_file import XBRLFile
from edinet.parser.aspects.business import Business

#先程ダウンロードしたデータを参照する
xbrl = XBRLFile("./S100OULM_1.xbrl")

#取得したxbrl データからparse する
content = xbrl.parse_by(Business).policy_environment_issue_etc
r_d = xbrl.parse_by(Business).research_and_development

# %%
#経営方針、経営環境及び対処すべき課題等の情報を取り出す
print(content)
# Out:
# None

# %%
#研究開発情報のデータを取り出す
print(r_d)
# Out:
# None

# %% [markdown]
# - 参考文献
# https://pypi.org/project/edinet-python/
